# %%
# %%HTML
# <<!DOCTYPE html>
# <html>
#   <head>
#     <meta charset="utf-8">
#     <title>lab1</title>
#   </head>
#   <body>
#     <h1><b><i><u>Greece </u></i></b></h1>
#     <p>Area: 131,957 km2</p>
#     <p>Population: 10.7 million as of 2018</p>
#     <h2>Government</h2>
#     <table>
#       <tr>
#         <td>President of the Hellenic Republic</td><td><a href="http://www.presidency.gr/">link</a></td>
#       </tr>
#       <tr>
#         <td>Prime Minister of the Hellenic Republic</td><td><a href="https://primeminister.gr/">link</a></td>
#       </tr>
#       <tr>
#         <td>Hellenic Parliament</td><td><a href="http://www.hellenicparliament.gr/">link</a></td>
#       </tr>
#       <tr>
#         <td>Greek National Tourism Organisation</td><td><a href="http://www.visitgreece.gr/">link</a></td>
#       </tr>
#       <tr>
#         <td>Greek News Agenda Newsletter</td><td><a href="http://www.greeknewsagenda.gr/">link</a></td>
#       </tr>
#     </table>
#
#   <h2>Celebrities</h2>
#   <ul>
#       <ul>
#         <li><a href="https://www.ranker.com/review/tiffani-thiessen/2244359?ref=morenode_1248816_199">Tiffani Thiessen</a></li>
#         <li><a href="https://www.ranker.com/review/jennifer-aniston/1281239?ref=node_name&pos=1&a=0&ltype=n&l=1248816">Jennifer Aniston</a></li>
#         <li><a href="https://www.ranker.com/review/john-stamos/1314812?ref=node_name&pos=3&a=0&ltype=n&l=1248816">John Stamos</a></li>
#         <li><a href="https://www.ranker.com/review/angie-harmon/464561?ref=node_name&pos=8&a=0&ltype=n&l=1248816">Angie Harmon</a></li>
#         <li><a href="https://www.ranker.com/review/tommy-lee/2256301?ref=node_name&pos=9&a=0&ltype=n&l=1248816">Tommy Lee</a></li>
#         <li><a href="https://www.ranker.com/review/mena-suvari/1563245?ref=node_name&pos=10&a=0&ltype=n&l=1248816">Mena Suvari</a></li>
#       </ul>
#   </ul>
#   <h2>Cultural and natural attractions</h2>
#   <table>
#     <tr>
#       <td>Mount Lycabettus</td><td><a href="https://www.inspirock.com/greece/athens/mount-lycabettus-a19348951">link</a></td>
#     </tr>
#     <tr>
#       <td>Amoudi Bay</td><td><a href="https://www.inspirock.com/greece/oia/amoudi-bay-a246483995">link</a></td>
#     </tr>
#     <tr>
#       <td>Fortress Spinalonga</td><td><a href="https://www.inspirock.com/greece/elounda/fortress-spinalonga-a620809903">link</a></td>
#     </tr>
#     <tr>
#       <td>Samaria Gorge National Park</td><td><a href="https://www.inspirock.com/greece/sfakia/samaria-gorge-national-park-a59663401">link</a></td>
#     </tr>
#     <tr>
#       <td>Melissani Cave</td><td><a href="https://www.inspirock.com/greece/sami/melissani-cave-a543422981">link</a></td>
#     </tr>
#   </table>
#   <svg xmlns="http://www.w3.org/2000/svg" width="1200" height="600" viewBox="0 0 10080 5040">
# 	<path style="fill:#338AF3;" d="M256,189.217h247.181c-6.419-23.814-16.175-46.255-28.755-66.783H256V189.217z"/>
# 	<path style="fill:#338AF3;" d="M96.643,456.348h318.713c23.363-18.608,43.399-41.21,59.069-66.783H37.574
# 		C53.245,415.137,73.281,437.74,96.643,456.348z"/>
# 	<path style="fill:#338AF3;" d="M89.043,61.939c-20.126,17.331-37.525,37.74-51.469,60.496h51.469V61.939z"/>
# 	<path style="fill:#338AF3;" d="M256,256c0-26.076,0-47.899,0-66.783H155.826V256H89.043v-66.783H8.819
# 		C3.08,210.511,0,232.893,0,256s3.08,45.489,8.819,66.783h494.363C508.92,301.489,512,279.107,512,256H256z"/>
# 	<path style="fill:#338AF3;" d="M256,0c-35.549,0-69.404,7.253-100.174,20.348v102.087H256c0-23.312,0-43.139,0-66.783h159.357
# 		C371.626,20.824,316.249,0,256,0z"/>
# </svg>
#   </body>
# </html>
# Out:
# <<!DOCTYPE html>
# <html>
#   <head>
#     <meta charset="utf-8">
#     <title>lab1</title>
#   </head>
#   <body>
#     <h1><b><i><u>Greece </u></i></b></h1>
#     <p>Area: 131,957 km2</p>
#     <p>Population: 10.7 million as of 2018</p>
#     <h2>Government</h2>
#     <table>
#       <tr>
#         <td>President of the Hellenic Republic</td><td><a href="http://www.presidency.gr/">link</a></td>
#       </tr>
#       <tr>
#         <td>Prime Minister of the Hellenic Republic</td><td><a href="https://primeminister.gr/">link</a></td>
#       </tr>
#       <tr>
#         <td>Hellenic Parliament</td><td><a href="http://www.hellenicparliament.gr/">link</a></td>
#       </tr>
#       <tr>
#         <td>Greek National Tourism Organisation</td><td><a href="http://www.visitgreece.gr/">link</a></td>
#       </tr>
#       <tr>
#         <td>Greek News Agenda Newsletter</td><td><a href="http://www.greeknewsagenda.gr/">link</a></td>
#       </tr>
#     </table>
#
#   <h2>Celebrities</h2>
# ...

# %%
def isprime(n):
    divisors = [ d for d in range(2,n//2+1) if n % d == 0 ]
    return 1 if not divisors else 0

def goldbach(n):
    for i in range(2,n//2+1):
        if isprime(i) and isprime(n-i):
            return i, n-i

def test_task_1():
    task_1(28)
    task_1(32)
    task_1(2)
    task_1(91)
    task_1('ewq')


def task_1(n=None):
    try:
        if n is None:
            n = int(input('Enter even integer greater than 2: '))
        if n <= 2 or n%2 != 0:
            raise ValueError
    except (TypeError, ValueError):
        print('This is incorrect number!')
    else:
        x, y = goldbach(n)
        print('Number {n} can be expresses as {x}+{y}'.format(n=n, x=x, y=y))


test_task_1()
# Out:
# Number 28 can be expresses as 5+23
# Number 32 can be expresses as 3+29
# This is incorrect number!
# This is incorrect number!
# This is incorrect number!

# %%
task_1()
# Out:
# Enter even integer greater than 2: 48
# Number 48 can be expresses as 5+43
